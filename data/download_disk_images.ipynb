# %%
import os
import pandas as pd
import requests
import urllib.request
from urllib.parse import urlparse, quote
import re
from disk_image_handling.c64_disk_image_processing import Corpus

# %% [markdown]
# # 1. Load data

# %%
with open('csv/mw_import.csv', encoding='utf-16') as main_dataset, open('csv/diskmags_csdb.csv', encoding='utf-8') as csdb_dataset, open('csv/diskmags_demozoo.csv', encoding='utf-8') as demozoo_dataset, open('csv/diskmags_pouet.csv', encoding='utf-8') as pouet_dataset:
    df_main = pd.read_csv(main_dataset)
    df_csdb = pd.read_csv(csdb_dataset)
    df_demozoo = pd.read_csv(demozoo_dataset)
    df_pouet = pd.read_csv(pouet_dataset)

# %% [markdown]
# ## 1.1 Create subset of German-language magazines for the Commodore 64

# %%
df_main_german = df_main[df_main['Magazine[Language]'].apply(lambda x: isinstance(x,str) and 'German' in x)]
df_main_german = df_main_german[df_main_german['Magazine[Systems]'].apply(lambda x: isinstance(x,str) and 'Commodore 64' in x)]
df_main_german['systems_lower'] = df_main_german['Magazine[Systems]'].apply(lambda x: x.lower() if isinstance(x, str) else None)
df_main_german.to_csv('csv/c64_diskmag_titles.csv', index=False)

# %% [markdown]
# ## 1.2 Prepare other datsets

# %%
df_csdb['system_lower'] = df_csdb['platform'].apply(lambda x: x.lower() if isinstance(x, str) else None)
df_demozoo['system_lower'] = df_demozoo['platform'].apply(lambda x: x.lower() if isinstance(x, str) else None)
df_pouet['system_lower'] = df_pouet['platform'].apply(lambda x: x.lower() if isinstance(x, str) else None)

# %% [markdown]
# # 2. Get the list of all issues

# %%
columns = ['title', 
           'issue', 
           'issue_normalized',
           'link',
           'download_links', 
           'release_converted', 
           'group']
issue_col = pd.DataFrame(columns=columns)

# %%
for index, row in df_main_german.iterrows():
    if not isinstance(row['systems_lower'], str): continue
    # Get values
    title = row['Title']
    system = row['systems_lower'].split('; ')
    source = row['Magazine[Source]'].split('; ')
    
    if 'CSDB' in source:
        subset_csdb = df_csdb[df_csdb['title']==title]
        subset_csdb = subset_csdb[columns]
        subset_csdb['source'] = 'CSDB'
        issue_col = pd.concat([issue_col, subset_csdb])
        
    if 'Demozoo' in source:
        subset_demozoo = df_demozoo[df_demozoo['title']==title]
        subset_demozoo = subset_demozoo[subset_demozoo['platform'].str.contains('Commodore 64')]
        subset_demozoo = subset_demozoo[columns]
        subset_demozoo['source'] = 'Demozoo'
        issue_col = pd.concat([issue_col, subset_demozoo])
        
    if 'Pouet' in source:
        subset_pouet = df_pouet[df_pouet['title']==title]
        subset_pouet = subset_pouet[subset_pouet['platform'].str.contains('Commodore 64')]
        subset_pouet = subset_pouet[columns]
        subset_pouet['source'] = 'Pouet'
        issue_col = pd.concat([issue_col, subset_pouet])

# %%
issue_col = issue_col.sort_values(by='issue_normalized', key=lambda x: x.str.lower())

# %%
issue_col.to_csv('csv/c64_diskmag_issues.csv', index=False)

# %% [markdown]
# # 3. Start download

# %%
base_path = 'disk_images_automatically_collected/'
#os.mkdir('../data/disk_images')
#os.chdir('disk_images')

# %%
downloaded_issues = set()

# %%
for index, row in issue_col.iterrows():
    title = row['title']
    issue = row['issue_normalized']
    download_links = row['download_links']
    
    if isinstance(download_links, str):
        download_links = download_links.split(', ')
    else:
        continue
    
    if issue in downloaded_issues:
        continue
    
    for url in download_links:
        if 'download.php' in url:
            continue
        try:
            folder_path = os.path.join(base_path, f'{title}/{issue}')
            parsed_url = urlparse(url)
            filename = os.path.basename(parsed_url.path)
            if not os.path.exists(folder_path):
                os.makedirs(folder_path)
            full_path = os.path.join(folder_path, filename)
            url = url.replace(' ', '')
            encoded_url = quote(url, safe=':/?#')
            urllib.request.urlretrieve(url, filename=full_path)
            downloaded_issues.add(issue)
            print(f'Downloading {filename}')
            
            break
        except Exception as e:
            print(f'Error downloading file: {e}')
# Out:
# Downloading actionnews01.zip
# Downloading actionnews02.zip
# Downloading actionnews03.zip
# Downloading actionnews04.zip
# Downloading Action_News_05.zip
# Downloading Action_News_06.zip
# Downloading actionnews08.zip
# Downloading Action_News_08.zip
# Downloading Action_News_09.zip
# Downloading atn1.zip
# Downloading atn2.zip
# Downloading atn3.zip
# Downloading atn4.zip
# Downloading atn5.zip
# Downloading atn6.zip
# Downloading Bioblech_01.zip
# Downloading Bioblech_02.zip
# Downloading bioblech03.zip
# Downloading biometal01.zip
# Downloading biometal02.zip
# Downloading biometal03.zip
# Downloading biometal04.zip
# Downloading chaos_1_.zip
# Downloading Chaos
# Downloading Chaos_03.zip
# Downloading CN5.zip
# Downloading DarkStar13.zip
# Downloading Digital-News-April-88-2Sides-ESI.zip
# Downloading Digital_News_88_02.zip
# Downloading Digital-News-88-01.zip
# Downloading Digital_News_88_02.zip
# Downloading Digital_news_RADWAR.d64
# Downloading digitaltalk_01.zip
# Downloading DigitalTalk_01.zip
# Downloading DT100.zip
# Downloading DT101.zip
# Downloading DT102.zip
# Downloading DT103.zip
# Downloading DT104.zip
# Downloading DT105.zip
# Downloading DT106.zip
# Downloading DT107.zip
# Downloading DT108.zip
# Downloading 109-side1.d64
# Downloading DigitalTalk_11.zip
# Downloading DigitalTalk_110.zip
# Downloading DigitalTalk111.zip
# Downloading DT112_A.d64
# Downloading DigitalTalk_12.zip
# Downloading DigitalTalk_13.zip
# Downloading digitaltalk14.zip
# Downloading digitaltalk15.zip
# Downloading digitaltalk16.zip
# Downloading digitaltalk_17.zip
# Downloading digitaltalk_18.zip
# Downloading digitaltalk19.zip
# Downloading DigitalTalk02.lzh
# Downloading DigitalTalk_20.zip
# Downloading digitaltalk21.zip
# Downloading digitaltalk_22.zip
# Downloading digitaltalk23.zip
# Downloading digitaltalk24.zip
# Downloading digitaltalk25.zip
# Downloading digitaltalk26.zip
# Downloading digitaltalk_27.zip
# Downloading digitaltalk_28.zip
# Downloading digitaltalk_29.zip
# Downloading DigitalTalk03.lzh
# Downloading digitaltalk_30.zip
# Downloading digitaltalk31.zip
# Downloading DigitalTalk_32.zip
# Downloading DigitalTalk_33.zip
# Downloading digitaltalk34.zip
# Downloading digitaltalk35.zip
# Downloading dt36.zip
# Downloading digitaltalk_37.zip
# Downloading digitaltalk38.zip
# Downloading digitaltalk39.zip
# Downloading digitaltalk04.zip
# Downloading digitaltalk40.zip
# Downloading digitaltalk_41.zip
# Downloading digitaltalk42.zip
# Downloading digitaltalk_43.zip
# Downloading digitaltalk44.zip
# Downloading digitaltalk45.zip
# Downloading dt46.zip
# Downloading DT
# Downloading DT
# Downloading digitaltalk_49.zip
# Downloading digitaltalk05.zip
# Downloading digitaltalk_50.zip
# Downloading DigitalTalk51.zip
# Downloading DT
# Downloading DT
# Downloading DigitalTalk54.zip
# Downloading DigitalTalk55.zip
# Downloading DT
# Downloading DigitalTalk57.zip
# Downloading DT %2358.zip
# Downloading DT
# Downloading digitaltalk06.zip
# Downloading dt_download_35_3eabb43d.zip
# Downloading DT
# Downloading DT
# Downloading DigitalTalk63.zip
# Downloading dt_download_39_4012ca55.zip
# Downloading DT %2365.zip
# Downloading DT
# Downloading dt_download_42_40e2e20e.zip
# Downloading DT
# Downloading DT
# Downloading digitaltalk07.zip
# Downloading DT %2370 low.zip
# Downloading DT %2371.zip
# Downloading DT %2372.zip
# Downloading DT %2373.zip
# Downloading DT
# Downloading DT %2375.zip
# Downloading DT %2376.zip
# Downloading dt77.zip
# Downloading DT
# Downloading DT79.zip
# Downloading DigitalTalk_08.zip
# Downloading DT
# Downloading DT
# Downloading DT
# Downloading DT
# Downloading DT
# Downloading DT
# Downloading DT86.zip
# Downloading DT
# Downloading DT
# Downloading DT
# Downloading dt09.zip
# Downloading DT
# Downloading digitaltalk91.zip
# Downloading dt092.zip
# Downloading dt093.zip
# Downloading dt094.zip
# Downloading dt095.zip
# Downloading dt096.zip
# Downloading dt097.zip
# Downloading dt098.zip
# Downloading DT99.zip
# Downloading Dynamic News
# Downloading tigerdisk_4years.zip
# Downloading Galaxy01_BothSides.zip
# Downloading Game-On-Issue-12-88-german-DVE.d64
# Downloading Helpline_001.d64
# Downloading Helpline_010.d64
# Downloading Helpline_011.d64
# Downloading Helpline_012.d64
# Downloading Helpline_013.d64
# Downloading Helpline_014.d64
# Downloading Helpline_015.d64
# Downloading Helpline_016.d64
# Downloading Helpline_017.d64
# Downloading Helpline_018.d64
# Downloading Helpline_019.d64
# Downloading Helpline_002.d64
# Downloading Helpline_020.d64
# Downloading Helpline_021.d64
# Downloading Helpline_022.d64
# Downloading Helpline_023.d64
# Downloading Helpline_024.d64
# Downloading Helpline_025.d64
# Downloading Helpline_026.d64
# Downloading Helpline_027.d64
# Downloading Helpline_028.d64
# Downloading Helpline_029.d64
# Downloading Helpline_003.d64
# Downloading Helpline_030.d64
# Downloading Helpline_031.d64
# Downloading Helpline_032.d64
# Downloading Helpline_033.d64
# Downloading Helpline_034.d64
# Downloading Helpline_035.d64
# Downloading Helpline_036.d64
# Downloading Helpline_037-Terragon_Software.d64
# Downloading 38.d64
# Downloading 39.d64
# Downloading Helpline_004.d64
# Downloading 40.d64
# Downloading 41.d64
# Downloading 42.d64
# Downloading 43.d64
# Downloading 44.d64
# Downloading 45.d64
# Downloading 46.d64
# Downloading 47.d64
# Downloading 48.d64
# Downloading 49.d64
# Downloading Helpline_005.d64
# Downloading Helpline_006.d64
# Downloading Helpline_007.d64
# Downloading Helpline_008.d64
# Downloading Helpline_009.d64
# Downloading Input-64-Issue-1-1988-TMS.d64
# Downloading Killerdrive10.D64
# Downloading killerdrive02.d64
# Downloading killerdrive5.d64
# Downloading killerdrive07.zip
# Downloading Killerdrive8.zip
# Downloading killerdrive9.zip
# Downloading Lotek64_01.pdf.rar
# Downloading Lotek64_11.pdf.rar
# Downloading fileretriever.php
# Downloading Lotek64_13.pdf
# Downloading Lotek64_14.pdf
# Downloading Lotek64_15.pdf
# Downloading fileretriever.php
# Downloading fileretriever.php
# Downloading lotek64-18.zip
# Downloading Lotek64_19.pdf
# Downloading Lotek64_02.pdf.rar
# Downloading fileretriever.php
# Downloading fileretriever.php
# Downloading Lotek64_23.pdf
# Downloading Lotek64_04.pdf.rar
# Downloading fileretriever.php
# Downloading fileretriever.php
# Downloading fileretriever.php
# Downloading fileretriever.php
# Downloading MagicCode01-ApolloDesigns.D64
# Downloading mm01.zip
# Downloading mm10_11.zip
# Downloading mm12.zip
# Downloading mm13.zip
# Downloading mm14.zip
# Downloading mm15.zip
# Downloading mm16.zip
# Downloading mm17.zip
# Downloading Mail_Madness_18.zip
# Downloading mm19.zip
# Downloading mm02.zip
# Error downloading file: <urlopen error <urlopen error ftp error: error_perm('550 Mail_Madness_2021[Telenova].zip: No such file or directory')>>
# Downloading mm20_21.zip
# Downloading mm22.zip
# Downloading mm23_24.zip
# Downloading mm25.zip
# Downloading mm26.zip
# Error downloading file: <urlopen error [WinError 10060] Ein Verbindungsversuch ist fehlgeschlagen, da die Gegenstelle nach einer bestimmten Zeitspanne nicht richtig reagiert hat, oder die hergestellte Verbindung war fehlerhaft, da der verbundene Host nicht reagiert hat>
# Downloading mm28.zip
# Downloading mm29.zip
# Downloading mm03.zip
# Downloading mm30.zip
# Downloading mm31.zip
# Downloading mm32.zip
# Downloading mm33.zip
# Downloading mm34.zip
# Downloading Mail_Madness_35.zip
# Downloading mm36.zip
# Downloading mm37.zip
# Downloading mm38.zip
# Downloading mm39.zip
# Downloading mm04.zip
# Downloading mm40.zip
# Downloading mm41.zip
# Downloading mm42.zip
